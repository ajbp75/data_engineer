# %%
#Libs
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import pandas as Pd

# %%
#sparkSession
spark = SparkSession.builder.appName("Sessao").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/01 12:19:06 WARN Utils: Your hostname, DESKTOP-FBCHK7G, resolves to a loopback address: 127.0.1.1; using 172.19.238.81 instead (on interface eth0)
# 26/02/01 12:19:06 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/01 12:19:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
#open first file
df_amazon = spark.read.option("header","True").option("inferSchema","True").csv(f"../raw/Amazon Sale Report.csv")

# %%
#check schema
df_amazon.printSchema()
# Out:
# root
#  |-- index: integer (nullable = true)
#  |-- Order ID: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Status: string (nullable = true)
#  |-- Fulfilment: string (nullable = true)
#  |-- Sales Channel : string (nullable = true)
#  |-- ship-service-level: string (nullable = true)
#  |-- Style: string (nullable = true)
#  |-- SKU: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Size: string (nullable = true)
#  |-- ASIN: string (nullable = true)
#  |-- Courier Status: string (nullable = true)
#  |-- Qty: integer (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- Amount: double (nullable = true)
#  |-- ship-city: string (nullable = true)
#  |-- ship-state: string (nullable = true)
#  |-- ship-postal-code: double (nullable = true)
#  |-- ship-country: string (nullable = true)
#  |-- promotion-ids: string (nullable = true)
#  |-- B2B: boolean (nullable = true)
#  |-- fulfilled-by: string (nullable = true)
# ...

# %%
#check number of registers
df_amazon.count()
# Out:
# 128975

# %%
#As Spark show truncated, I did a few amouth and I coverted for Pandas to I´ll see de quality data
#df_amazon.show(truncate=True)
df_amazon_pandas = df_amazon.limit(10).toPandas()

# %%
#Check Data
df_amazon_pandas.head(3)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
#
#   Category  ... currency  Amount    ship-city   ship-state ship-postal-code  \
# 0      Set  ...      INR  647.62       MUMBAI  MAHARASHTRA         400081.0
# 1    kurta  ...      INR  406.00    BENGALURU    KARNATAKA         560085.0
# 2    kurta  ...      INR  329.00  NAVI MUMBAI  MAHARASHTRA         410210.0
#
#    ship-country                                      promotion-ids    B2B  \
# ...
